# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dict1 = {
    "company_name":[
        'Allied_Signal',
        'Bankers_Trust',
        'General Mills',
        'ITT_Industries',
        'Jp_Morgan_co',
        'Lehman Brothers',
        'Marriott',
        'MCI',
        'MerrillLynch',
        'Microsoft',
        'Morgan_Stanley',
        'Sun Microsystems',
        'Travelers',
        'US Airways',
        'Warner-Lambert'],
    
         "measure":[24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00]    
}
# Access the list of company names
company_names = dict1["company_name"]

# %%
df = pd.DataFrame(dict1)

# %%
df.mean()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17024\3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# measure    33.271333
# dtype: float64

# %%
df.var()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17024\1568254755.py:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# measure    287.146612
# dtype: float64

# %%
df.std()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17024\3390915376.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# measure    16.945401
# dtype: float64

# %%
plt.pie(df.measure,labels = df.company_name)
plt.legend(title = "company_info:")
